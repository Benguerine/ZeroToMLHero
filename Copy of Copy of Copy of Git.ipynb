# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from getpass import getpass

# Step 1: Set working directory to your repo folder
folder_path = "/content/drive/MyDrive/Master_ML_From_Zero_To_Hero"
os.chdir(folder_path)

# Step 2: Initialize Git and configure your identity
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

# Step 3: Rename current branch to 'main'
# !git branch -M main

# Step 4: Ask user for GitHub token securely
token = getpass("Enter your GitHub token: ")

# Step 5: Set remote origin (replace existing if needed)
# !git remote remove origin 2> /dev/null
repo_url = f"https://{token}@github.com/Benguerine/Benguerine/ZeroToMLHero.git"
# !git remote add origin "{repo_url}"

# Step 6: Stage and commit all files
# !git add .
# !git commit -m "Initial commit from Colab"

# Step 7: Push to GitHub
# !git push -u origin main
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/Master_ML_From_Zero_To_Hero/.git/
# Enter your GitHub token: ··········
# [main (root-commit) 766ac22] Initial commit from Colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 Copy of Copy of Copy of Git.ipynb
# remote: Not Found
# fatal: repository 'https://github.com/Benguerine/Benguerine/ZeroToMLHero.git/' not found
