# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from getpass import getpass

# Step 1: Set working directory to your repo folder
folder_path = "/content/drive/MyDrive/Master_ML_From_Zero_To_Hero"
os.chdir(folder_path)

# Step 2: Initialize Git and configure your identity
# !git init
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git config --global user.name "Benguerine"

# Step 3: Rename current branch to 'main'
# !git branch -M main

# Step 4: Ask user for GitHub token securely
token = getpass("Enter your GitHub token: ")

# Step 5: Set remote origin
# !git remote remove origin 2> /dev/null
repo_url = f"https://{token}@github.com/Benguerine/ZeroToMLHero.git"
# !git remote add origin "{repo_url}"

# Step 6: Stage and commit all files
# !git add .
# !git commit -m "Initial commit from Colab"

# Step 7: Push (force if needed)
# !git push -u origin main --force
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Master_ML_From_Zero_To_Hero/.git/
# Enter your GitHub token: ··········
# [main 9c9f42b] Initial commit from Colab
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite Machine Learning notes/Introduction and Fundamentals/Introduction_to_Machine_Learning.ipynb (86%)
