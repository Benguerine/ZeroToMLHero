# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##**Code**

# %%
import os
from getpass import getpass

folder_path = "/content/drive/MyDrive/Master_ML_From_Zero_To_Hero"
os.chdir(folder_path)

# !git init
# !git config --global user.name "Benguerine"
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git branch -M main

token = getpass("Enter your GitHub token: ")
repo_owner = "Benguerine"
repo_name = "ZeroToMLHero"
repo_url = f"https://{repo_owner}:{token}@github.com/{repo_owner}/{repo_name}.git"

# !git remote remove origin 2> /dev/null
# !git remote add origin "{repo_url}"

# !git add .
# !git commit -m "Initial commit from Colab"
# !git push -u origin main --force
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Master_ML_From_Zero_To_Hero/.git/
# Enter your GitHub token: ··········
# [main b2027f3] Initial commit from Colab
#  1 file changed, 1 insertion(+)
#  create mode 100644 Copy of Copy of Copy of Git.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 2.19 KiB | 249.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/Benguerine/ZeroToMLHero.git
#    3639deb..b2027f3  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
