# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**Code**

# %%
import os
from getpass import getpass

folder_path = "/content/drive/MyDrive/Master_ML_From_Zero_To_Hero"
os.chdir(folder_path)

# !git init
# !git config --global user.name "Benguerine"
# !git config --global user.email "mohammed.benguerine.1102@univ-sba.dz"
# !git branch -M main

token = getpass("Enter your GitHub token: ")
repo_owner = "Benguerine"
repo_name = "ZeroToMLHero"
repo_url = f"https://{repo_owner}:{token}@github.com/{repo_owner}/{repo_name}.git"

# !git remote remove origin 2> /dev/null
# !git remote add origin "{repo_url}"

# !git add .
# !git commit -m "Initial commit from Colab"
# !git push -u origin main --force
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Master_ML_From_Zero_To_Hero/.git/
# Enter your GitHub token: ··········
# [main bafe9e2] Initial commit from Colab
#  4 files changed, 3 insertions(+), 2 deletions(-)
#  delete mode 100644 Copy of Copy of Copy of Git.ipynb
#  create mode 100644 Git.ipynb
#  create mode 100644 Machine Learning notes/Specialized Techniques/Neural_Network_with_GA.ipynb
#  rewrite Machine Learning notes/Unsupervised Learning/Clustering.ipynb (86%)
# remote: Invalid username or token. Password authentication is not supported for Git operations.
# fatal: Authentication failed for 'https://github.com/Benguerine/ZeroToMLHero.git/'
